# %%
import numpy as np
import matplotlib.pyplot as plt
from statistics import mean

# problem 1
nums = np.random.normal(50, 25, 200)
plt.hist(nums)
print(mean(nums))
plt.show()

nums2 = np.random.uniform(50, 25, 200)
plt.hist(nums2)
print(mean(nums))
plt.show()
# Out:
# 48.21021961711086
# 48.21021961711086

# %%
# problem 2
temp = 298
boltz_k = 1.38 * 10**-23
Kav = (3/2) * boltz_k * temp
m = 4.65e-26

avg_v = ((2 * Kav)/m)**0.5
print(avg_v)
vs = np.random.normal(avg_v, 10**-10.7, 1000)
plt.hist(vs, rwidth=0.8)
plt.show()
# Out:
# 6.168599999999999e-21
# 515.0884671901109
